# %% [markdown]
# # Life Expectancy
#
# .[data source]. (https://data.worldbank.org/indicator/SP.DYN.LE00.IN)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
! head Data/1_Life_Expectancy/API_SP.DYN.LE00.IN_DS2_en_csv_v2_5795729.csv
# Out:
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2023-07-25",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022",
# ...

# %%
df = pd.read_csv("Data/1_Life_Expectancy/API_SP.DYN.LE00.IN_DS2_en_csv_v2_5795729.csv", header = 2, index_col=[0, 1, 2, 3])

df.head()
# Out:
#                                                                                                       1960  \
# Country Name                Country Code Indicator Name                          Indicator Code
# Aruba                       ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  64.152000
# Africa Eastern and Southern AFE          Life expectancy at birth, total (years) SP.DYN.LE00.IN  44.085552
# Afghanistan                 AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.535000
# Africa Western and Central  AFW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  37.845152
# Angola                      AGO          Life expectancy at birth, total (years) SP.DYN.LE00.IN  38.211000
#
#                                                                                                       1961  \
# Country Name                Country Code Indicator Name                          Indicator Code
# ...

# %% [markdown]
# Check missing Data

# %%
df['2021']
# Out:
# Country Name                 Country Code  Indicator Name                           Indicator Code
# Aruba                        ABW           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    74.626000
# Africa Eastern and Southern  AFE           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    62.454590
# Afghanistan                  AFG           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    61.982000
# Africa Western and Central   AFW           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    56.988657
# Angola                       AGO           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    61.643000
#                                                                                                         ...
# Kosovo                       XKX           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    76.806000
# ...

# %%
df['2021'].dropna()
# Out:
# Country Name                 Country Code  Indicator Name                           Indicator Code
# Aruba                        ABW           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    74.626000
# Africa Eastern and Southern  AFE           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    62.454590
# Afghanistan                  AFG           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    61.982000
# Africa Western and Central   AFW           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    56.988657
# Angola                       AGO           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    61.643000
#                                                                                                         ...
# Kosovo                       XKX           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    76.806000
# ...

# %% [markdown]
# Plot the Data

# %%
life_expectancy = df.groupby(level = 0).first().transpose()
life_expectancy.head()
# Out:
# Country Name  Afghanistan  Africa Eastern and Southern  \
# 1960               32.535                    44.085552
# 1961               33.068                    44.386697
# 1962               33.547                    44.752182
# 1963               34.016                    44.913159
# 1964               34.494                    45.479043
#
# Country Name  Africa Western and Central  Albania  Algeria  American Samoa  \
# 1960                           37.845152   54.439   40.532             NaN
# 1961                           38.164950   55.634   40.516             NaN
# 1962                           38.735102   56.671   39.323             NaN
# 1963                           39.063715   57.844   42.908             NaN
# 1964                           39.335360   58.983   42.788             NaN
#
# Country Name  Andorra  Angola  Antigua and Barbuda  Arab World  ...  \
# 1960              NaN  38.211               61.550   44.972899  ...
# ...

# %%
list(life_expectancy.columns)
# Out:
# ['Afghanistan',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
# ...

# %%
life_expectancy_subset = life_expectancy[['United States', 'Russian Federation', 'China', 'India', 'Malaysia', 'South Africa']]

# %%
life_expectancy_subset.plot()
# Out:
# <Axes: >
